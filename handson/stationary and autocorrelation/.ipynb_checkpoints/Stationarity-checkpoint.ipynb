# %% [markdown]
# # Imports

# %%
import statsmodels as ss
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Section 1: Stationary Time Series
#
# In this lesson, we will explore stationary time series. Specifically, we'll discuss what it means for time series to be stationary and show examples of a few time series that are not stationary.
#
# As before, we'll generate datasets from scratch to help you establish a deeper understanding of what it means for time series data to be stationary or nonstationary.

# %%
# reproducibility
np.random.seed(42)

# data
time = np.arange(100)
stationary = np.random.normal(loc=0, scale=1.0, size=len(time))

# %%
def run_sequence_plot(x, y, title, xlabel="time", ylabel="series"):
    plt.plot(x, y, 'k-')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(alpha=0.3);

# %%
run_sequence_plot(time, stationary, "Stationary TS")

# %% [markdown]
# ### Autocorrelation Structure

# %%
# seed to start series
seed = 3.14

# create autocorrelation data
lagged = np.empty_like(time, dtype='float')
for t in time:
    lagged[t] = seed + np.random.normal(loc=0, scale=2.5, size=1)
    seed = lagged[t]
# Out:
# Lagged:  5.455443868829104
# Seed:  1.8331924487024014
# Lagged:  10.22898547000443
# Seed:  4.455715513294624
# Lagged:  6.732566535456577
# Seed:  2.694856286937726
# Lagged:  8.139989627183004
# Seed:  -0.8262969539711729
# Lagged:  6.513383204378437
# Seed:  -4.717869887780932
# Lagged:  5.295569744966697
# Seed:  -3.2028450094168326
# Lagged:  3.814584934369524
# Seed:  -6.40391839065754
# Lagged:  1.654608010169984
# Seed:  -2.0169329356966283
# Lagged:  1.7759120800320516
# Seed:  -7.2217564554059335
# Lagged:  -0.30146321099554285
# Seed:  -2.9806155346808376
# Lagged:  0.37467885345405416
# Seed:  -2.4530718666742914
# Lagged:  0.24908357983121177
# Seed:  -2.6948546463502723
# Lagged:  -0.34828653733481263
# Seed:  -4.057152363372646
# Lagged:  -2.6171956924388073
# Seed:  -3.0593120774924687
# Lagged:  -4.059124018859639
# Seed:  -3.1533988335545895
# Lagged:  -2.170645954295249
# Seed:  -0.39514412851328595
# Lagged:  -0.9183529852342971
# Seed:  -0.10957500685818683
# Lagged:  -3.362241097230675
# Seed:  0.26617939679650715
# Lagged:  -3.1139103336576106
# Seed:  -0.6428511337381325
# Lagged:  -1.235442525228138
# Seed:  -0.7852151930408011
# Lagged:  -5.408955728031567
# Seed:  -0.015710770810653196
# Lagged:  -4.050555247081729
# Seed:  -4.291131752452217
# Lagged:  -5.707114644446346
# Seed:  -7.6615953077164995
# Lagged:  -4.280617972963448
# Seed:  -5.803435072659712
# Lagged:  -6.18876586431974
# Seed:  -5.376271477339857
# Lagged:  -10.700971115981037
# Seed:  -5.836229818221556
# Lagged:  -14.769827210688945
# Seed:  -5.790144985558073
# Lagged:  -14.64961484403549
# Seed:  -4.921190722153895
# Lagged:  -14.000308589731786
# Seed:  -6.270589922927298
# Lagged:  -16.26110015249281
# Seed:  -8.21635173643308
# Lagged:  -14.664619005549374
# Seed:  -7.7267385986888755
# Lagged:  -18.818419161221776
# Seed:  -10.172670542726456
# Seed:  -3.3016719720571195
# Lagged:  -29.537048638915536
# Seed:  -1.7499917281804245
# Lagged:  -28.690807620179502
# Seed:  -1.30573922584729
# Lagged:  -29.729027404931504
# Seed:  -4.644100122622543
# Lagged:  -28.14707273966579
# Seed:  -3.693605495107635
# Lagged:  -22.470340595154802
# Seed:  -2.1671411318980773
# Lagged:  -22.015674957508566
# Seed:  -0.7676650120704778
# Lagged:  -21.395123491757726
# Seed:  1.9342868018160766
# Lagged:  -22.543525740608338
# Seed:  4.019092188188337
# Lagged:  -24.668136664270317
# Seed:  5.167042386259428
# Lagged:  -22.592297122909702
# Seed:  4.991628107612811
# Lagged:  -24.73250668768187
# Seed:  0.8392257738228324
# Lagged:  -24.55359109463339
# Seed:  1.913271321654297
# Lagged:  -25.747734711546183
# Seed:  2.4324905395620746
# Lagged:  -24.550285147180205
# Seed:  3.1114376325505084
# Lagged:  -23.716129883962832
# Seed:  -0.08043380700026503
# Lagged:  -21.122280023318083
# Seed:  -2.783075158020921
# Lagged:  -22.39732102045495
# Seed:  -0.15019302468866202
# Lagged:  -23.07200835868838
# Seed:  -0.24908090933029964
# Lagged:  -25.518917648144146
# Seed:  1.4546708341012613
# Lagged:  -26.629650798334424
# Seed:  1.5254667744274142
# Lagged:  -25.686399565722294
# Seed:  1.599857123166777

# %%
# Out:
# array([ 0.35778736,  0.56078453,  1.08305124,  1.05380205, -1.37766937,
#        -0.93782504,  0.51503527,  0.51378595,  0.51504769,  3.85273149,
#         0.57089051,  1.13556564,  0.95400176,  0.65139125, -0.31526924,
#         0.75896922, -0.77282521, -0.23681861, -0.48536355,  0.08187414,
#         2.31465857, -1.86726519,  0.68626019, -1.61271587, -0.47193187,
#         1.0889506 ,  0.06428002, -1.07774478, -0.71530371,  0.67959775,
#        -0.73036663,  0.21645859,  0.04557184, -0.65160035,  2.14394409,
#         0.63391902, -2.02514259,  0.18645431, -0.66178646,  0.85243333,
#        -0.79252074, -0.11473644,  0.50498728,  0.86575519, -1.20029641,
#        -0.33450124, -0.47494531, -0.65332923,  1.76545424,  0.40498171,
#        -1.26088395,  0.91786195,  2.1221562 ,  1.03246526, -1.51936997,
#        -0.48423407,  1.26691115, -0.70766947,  0.44381943,  0.77463405,
#        -0.92693047, -0.05952536, -3.24126734, -1.02438764, -0.25256815,
#        -1.24778318,  1.6324113 , -1.43014138, -0.44004449,  0.13074058,
#         1.44127329, -1.43586215,  1.16316375,  0.01023306, -0.98150865,
#         0.46210347,  0.1990597 , -0.60021688,  0.06980208, -0.3853136 ,
#         0.11351735,  0.66213067,  1.58601682, -1.2378155 ,  2.13303337,
#        -1.9520878 , -0.1517851 ,  0.58831721,  0.28099187, -0.62269952,
#        -0.20812225, -0.49300093, -0.58936476,  0.8496021 ,  0.35701549,
#        -0.6929096 ,  0.89959988,  0.30729952,  0.81286212,  0.62962884])
